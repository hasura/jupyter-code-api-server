# %%
GRAPHQL_ENDPOINT = ""
ADMIN_SECRET = ""

from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport

gql_headers = dict()
gql_headers['x-hasura-admin-secret'] = ADMIN_SECRET

# Create a GraphQL client with the request transport
transport = RequestsHTTPTransport(
    url=GRAPHQL_ENDPOINT, headers=gql_headers)
client = Client(transport=transport)

# Send the GraphQL request
gql_query = gql("""
        mutation insertItems {
                insert_base_products(objects: [
            {
                id : 1,
                name: "Luminex AirPlus",
                description: "Experience the ultimate comfort and breathability with Luminex AirPlus, the lightweight and stylish athletic shoes designed to support your every step."
            },
            {
                id : 2,
                name: "VitaBlend Pro",
                description: "Introducing VitaBlend Pro, the versatile high-speed blender that effortlessly prepares smoothies, soups, and sauces, making healthy eating easier than ever."
            },
            {
                id : 3,
                name: "EcoFrost FridgeX",
                description: "Keep your food fresh and your energy bills low with EcoFrost FridgeX, the eco-friendly refrigerator with advanced cooling technology."
            },
            {
                id : 4,
                name: "PureGlow Revive",
                description: "Transform your skincare routine with PureGlow Revive, a rejuvenating facial mask that nourishes and revitalizes your skin, leaving it radiant and youthful."
            },
            {
                id : 5,
                name: "StreamRhythm Soundbar",
                description: "Enhance your home entertainment experience with StreamRhythm Soundbar, delivering immersive audio and powerful bass for your favorite movies and music."
            },
            {
                id : 6,
                name: "BioCharge Smartwatch",
                description: "Stay connected and monitor your health on the go with BioCharge Smartwatch, featuring advanced fitness tracking and heart rate monitoring capabilities."
            },
            {
                id : 7,
                name: "ScentSation Aromatherapy",
                description: "Create a relaxing ambiance in your home with ScentSation Aromatherapy, a set of essential oils carefully blended to soothe and uplift your senses."
            },
            {
                id : 8,
                name: "FlexiFit DeskPro",
                description: "Upgrade your workspace with FlexiFit DeskPro, an ergonomic adjustable desk that promotes better posture and reduces strain during long work hours."
            },
            {
                id : 9,
                name: "GlowGrip PhoneCase",
                description: "Protect and illuminate your smartphone with GlowGrip PhoneCase, featuring a slim design and a built-in LED light for better selfies and video calls."
            },
            {
                id : 10,
                name: "CulinaryMast Chef's Knife",
                description: "Unleash your inner chef with CulinaryMast Chef's Knife, expertly crafted for precision and control, making every slicing and chopping task effortless."
            },
            {
                id : 11,
                name: "BotanicEase Indoor Garden",
                description: "Bring nature indoors and grow your favorite herbs and plants year-round with BotanicEase Indoor Garden, featuring automated watering and LED grow lights."
            },
            {
                id : 12,
                name: "SonicGlide Electric Toothbrush",
                description: "Achieve a bright smile and healthier gums with SonicGlide Electric Toothbrush, utilizing sonic technology for superior plaque removal and dental care."
            },
            {
                id : 13,
                name: "MegaCharge Power Bank",
                description: "Never run out of power on your devices with MegaCharge Power Bank, a high-capacity portable charger with multiple USB and wireless charging options."
            },
            {
                id : 14,
                name: "AquaThirst Water Filter",
                description: "Enjoy clean and refreshing water with AquaThirst Water Filter, utilizing advanced filtration technology to remove impurities and enhance taste."
            },
            {
                id : 15,
                name: "SolarBloom Garden Lights",
                description: "Illuminate your outdoor spaces with SolarBloom Garden Lights, harnessing solar energy to cast a warm and enchanting glow in your garden or patio."
            },
            {
                id : 16,
                name: "BioZenith Air Purifier",
                description: "Breathe easier and improve indoor air quality with BioZenith Air Purifier, featuring HEPA filtration and smart sensors for automatic air purification."
            },
            {
                id : 17,
                name: "TerraTrek Hiking Backpack",
                description: "Embark on your adventures with TerraTrek Hiking Backpack, designed for durability and comfort, with ample storage space for all your outdoor gear."
            },
            {
                id : 18,
                name: "CocoaLux Hot Chocolate Maker",
                description: "Indulge in rich and creamy hot chocolate with CocoaLux Hot Chocolate Maker, offering customizable flavors and frothing options for a decadent treat."
            },
            {
                id : 19,
                name: "UrbanBeat Noise-Cancelling Headphones",
                description: "Immerse yourself in your favorite music without distractions with UrbanBeat Noise-Cancelling Headphones, delivering clear and powerful sound."
            },
            {
                id : 20,
                name: "ZenMist Ultrasonic Diffuser",
                description: "Create a calming atmosphere with ZenMist Ultrasonic Diffuser, dispersing soothing aromas and gentle mist for relaxation and stress relief."
            },
            {
                id : 21,
                name: "TechNova Wireless Earbuds",
                description: "Experience wireless freedom and crystal-clear audio with TechNova Wireless Earbuds, designed for comfort and seamless connectivity."
            },
            {
                id : 22,
                name: "RevitaBrew Coffee Maker",
                description: "Brew the perfect cup of coffee every time with RevitaBrew Coffee Maker, featuring precise temperature control and a built-in grinder for fresh beans."
            },
            {
                id : 23,
                name: "FlexiWave Yoga Mat",
                description: "Enhance your yoga practice with FlexiWave Yoga Mat, offering exceptional grip and support for various poses and exercises."
            },
            {
                id : 24,
                name: "SwiftServe SSD Drive",
                description: "Boost your computer's performance and storage with SwiftServe SSD Drive, providing fast read and write speeds for smoother computing."
            },
            {
                id : 25,
                name: "NatureTrail Trekking Poles",
                description: "Conquer rugged terrains with confidence using NatureTrail Trekking Poles, featuring lightweight and adjustable poles for stability and balance."
            },
            {
                id : 26,
                name: "CafeViva Espresso Machine",
                description: "Enjoy barista-quality espresso at home with CafeViva Espresso Machine, offering a compact design and easy-to-use functionality."
            },
            {
                id : 27,
                name: "GlideWell Roller Skates",
                description: "Rediscover the joy of skating with GlideWell Roller Skates, designed for smooth gliding and a comfortable fit for all skill levels."
            },
            {
                id : 28,
                name: "FreshBloom Flower Subscription",
                description: "Brighten up your space with FreshBloom Flower Subscription, delivering a delightful selection of fresh flowers to your doorstep regularly."
            },
            {
                id : 29,
                name: "BioCharge Pro Fitness Tracker",
                description: "Stay motivated and track your fitness progress with BioCharge Pro Fitness Tracker, offering comprehensive activity monitoring and heart rate analysis."
            },
            {
                id : 30,
                name: "EcoClean Dishwasher Tablets",
                description: "Effortlessly remove tough stains and grease with EcoClean Dishwasher Tablets, providing eco-friendly cleaning for sparkling dishes."
            },
            {
                id : 31,
                name: "AeroSwift Running Shoes",
                description: "Reach new speeds with AeroSwift Running Shoes, engineered for optimal performance and cushioning to help you excel on the track or trail."
            },
            {
                id : 32,
                name: "ComfyNest Memory Foam Pillow",
                description: "Experience the ultimate comfort and support for a restful night's sleep with ComfyNest Memory Foam Pillow, contouring to your unique shape."
            },
            {
                id : 33,
                name: "UrbanDash Electric Scooter",
                description: "Effortlessly commute in style with UrbanDash Electric Scooter, featuring a foldable design and long-lasting battery for smooth rides."
            },
            {
                id : 34,
                name: "BotanicaLife Herbal Tea Collection",
                description: "Savor the soothing flavors and health benefits of BotanicaLife Herbal Tea Collection, crafted with a blend of handpicked herbs and botanicals."
            },
            {
                id : 35,
                name: "HydroFlow Stainless Steel Bottle",
                description: "Stay hydrated on the go with HydroFlow Stainless Steel Bottle, keeping your beverages cold or hot for extended periods."
            },
            {
                id : 36,
                name: "NovaGlow Skincare Set",
                description: "Rejuvenate your skin with NovaGlow Skincare Set, featuring a range of natural and effective products for a radiant complexion."
            },
            {
                id : 37,
                name: "FitBeat Heart Rate Monitor",
                description: "Maximize your workouts and monitor your heart rate accurately with FitBeat Heart Rate Monitor, suitable for various fitness activities."
            },
            {
                id : 38,
                name: "UrbanHarmony City Bike",
                description: "Navigate city streets with ease using UrbanHarmony City Bike, combining style and functionality for a comfortable urban cycling experience."
            },
            {
                id : 39,
                name: "EcoEssentials Reusable Bags",
                description: "Reduce single-use plastic waste with EcoEssentials Reusable Bags, a set of eco-friendly and durable alternatives for shopping and storage."
            },
            {
                id : 40,
                name: "TranquilAura Essential Oil Diffuser",
                description: "Create a serene ambiance with TranquilAura Essential Oil Diffuser, featuring a minimalist design and gentle color-changing lights."
            },
            {
                id : 41,
                name: "iGlow Wireless Charging Pad",
                description: "Charge your compatible devices effortlessly with iGlow Wireless Charging Pad, offering fast and convenient wireless charging technology."
            },
            {
                id : 42,
                name: "EcoStep Bamboo Toothbrush",
                description: "Make an eco-conscious choice with EcoStep Bamboo Toothbrush, crafted from sustainable bamboo and soft bristles for effective oral care."
            },
            {
                id : 43,
                name: "LuxeShade Beach Umbrella",
                description: "Stay shaded and protected from the sun with LuxeShade Beach Umbrella, featuring a stylish design and UV-blocking fabric."
            },
            {
                id : 44,
                name: "PetPals Interactive Toy Set",
                description: "Keep your furry friend entertained for hours with PetPals Interactive Toy Set, designed to stimulate their natural instincts and playfulness."
            },
            {
                id : 45,
                name: "RapidScribe Note-Taking Pen",
                description: "Streamline your note-taking with RapidScribe Note-Taking Pen, converting your handwritten notes into digital text effortlessly."
            },
            {
                id : 46,
                name: "PurePetals Body Wash",
                description: "Indulge in a luxurious shower experience with PurePetals Body Wash, offering a gentle and nourishing formula for soft, supple skin."
            },
            {
                id : 47,
                name: "HarmonyBud True Wireless Earphones",
                description: "Experience true wireless freedom and superior sound quality with HarmonyBud True Wireless Earphones, perfect for active lifestyles."
            },
            {
                id : 48,
                name: "SolarSense Portable Charger",
                description: "Harness the power of the sun with SolarSense Portable Charger, providing a sustainable and reliable energy source for your devices."
            },
            {
                id : 49,
                name: "AirTrek Pro Luggage Set",
                description: "Travel in style and convenience with AirTrek Pro Luggage Set, featuring durable and spacious suitcases with smooth-rolling wheels."
            },
            {
                id : 50,
                name: "FreshBreeze Car Air Freshener",
                description: "Keep your car smelling fresh and inviting with FreshBreeze Car Air Freshener, offering long-lasting and delightful scents."
            },
            {
                id : 51,
                name: "EcoMotion Bamboo Yoga Blocks",
                description: "Enhance your yoga practice with EcoMotion Bamboo Yoga Blocks, providing support and stability for various poses and stretches."
            },
            {
                id : 52,
                name: "UrbanTech Smart Thermostat",
                description: "Efficiently control your home's temperature and save energy with UrbanTech Smart Thermostat, compatible with smart home systems."
            }
        ]) {
                affected_rows
            }
        }
    """)
client.execute(gql_query, variable_values={})
