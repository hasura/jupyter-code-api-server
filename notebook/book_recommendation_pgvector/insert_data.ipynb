# %%
# Open psql on terminal
# psql <connection string>
# Enable pgvector extension 
# CREATE EXTENSTION VECTOR;

# Create tables
# CREATE TABLE books (
#     id BIGSERIAL PRIMARY KEY,
#     name TEXT,
#     description TEXT,
#     author TEXT,
#     genre TEXT
# );

# CREATE TABLE books_embeddings (
# 	id BIGSERIAL PRIMARY KEY,
# 	book_id BIGINT REFERENCES books(id),
# 	embedding VECTOR(1536)
# );

# CREATE OR REPLACE FUNCTION insert_books_embedding(
#     book_id BIGINT,
#     embedding TEXT
# )
# RETURNS books_embeddings LANGUAGE plpgsql AS $$
# DECLARE
#     new_record books_embeddings;
# BEGIN
#     INSERT INTO books_embeddings (book_id, embedding)
#     VALUES (book_id, embedding::vector)
#     RETURNING * INTO new_record;    
#     RETURN new_record;
# END;
# $$;

# CREATE FUNCTION find_books_by_desc_similarity(book_query_embedding text)
# RETURNS SETOF books AS $$
# 	select b.* 
# 	FROM books_embeddings be
# 	JOIN books b on be.book_id = b.id
# 	ORDER BY
# 		be.embedding <-> book_query_embedding::vector
# 	LIMIT 10
# $$ LANGUAGE sql STABLE;

# %%
GRAPHQL_ENDPOINT = ""
ADMIN_SECRET = ""

from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport

gql_headers = dict()
gql_headers['x-hasura-admin-secret'] = ADMIN_SECRET

# Create a GraphQL client with the request transport
transport = RequestsHTTPTransport(
    url=GRAPHQL_ENDPOINT, headers=gql_headers)
client = Client(transport=transport)

# Send the GraphQL request
gql_query = gql("""
                mutation insert_books {
                insert_books(objects: [
                    {name: "The Silent Whisper", description: "A suspense thriller revolving around a series of unexpected events shaking a quiet suburban neighborhood.", author: "Alice Burrow", genre: "Thriller"},
                    {name: "The Last Enchantment", description: "An epic fantasy tale of knights, magic and the struggle for power in a divided kingdom.", author: "Arthur Pendragon", genre: "Fantasy"},
                    {name: "Dystopia Unveiled", description: "A chilling dystopian novel depicting a terrifying future of surveillance and totalitarianism.", author: "Bryan Orwell", genre: "Dystopian"},
                    {name: "The Timeless Voyage", description: "A science fiction saga of interstellar travel, first contact, and the challenges of communicating across the cosmos.", author: "Cara Stellar", genre: "Science Fiction"},
                    {name: "Haunted Shadows", description: "A spine-chilling horror tale of a haunted house, dark secrets, and the eerie presence lurking in the shadows.", author: "Damien Ghostly", genre: "Horror"},
                    {name: "Love's Silent Song", description: "A heartwarming romance novel about finding love in unexpected places amidst life's twists and turns.", author: "Ella Heart", genre: "Romance"},
                    {name: "Whispers of the Past", description: "A historical fiction weaving together tales of love, war, and the indomitable spirit of a bygone era.", author: "Fiona Timeless", genre: "Historical Fiction"},
                    {name: "Murder in High Heels", description: "A classic detective story of solving a high-profile murder case in a world of glamour and secrets.", author: "George Sleuth", genre: "Mystery"},
                    {name: "The Wilderness Within", description: "An inspiring adventure novel exploring the breathtaking beauty and dangers of the great outdoors.", author: "Hank Explorer", genre: "Adventure"},
                    {name: "The Comedy of Errors", description: "A humor-filled narrative exploring the comedic side of everyday life's ups and downs.", author: "Ivy Laughter", genre: "Humor"},
                    {name: "Beyond The Horizon", description: "An explorer's narrative taking readers on a thrilling journey to uncharted territories and the lessons learned on the way.", author: "Jack Frontier", genre: "Adventure"},
                    {name: "The Veil of Mystery", description: "A gripping mystery novel that delves into the mind of a genius detective solving a series of eerie crimes.", author: "Kara Mystery", genre: "Mystery"},
                    {name: "The Heart's Whisper", description: "A touching romance novel about the unspoken love between two childhood friends facing life's adversities together.", author: "Lara Love", genre: "Romance"},
                    {name: "The Dance of Destiny", description: "A mesmerizing historical novel depicting the lives of royalty amidst the changing political landscape of ancient kingdoms.", author: "Maria Dynasty", genre: "Historical Fiction"},
                    {name: "The Ghost of Time", description: "A speculative fiction exploring the realms of time travel, the butterfly effect, and the destiny of mankind.", author: "Nathan Time", genre: "Science Fiction"},
                    {name: "The Laughter of Love", description: "A romantic comedy showcasing the hilarious and heartwarming journey of finding true love.", author: "Olivia Joy", genre: "Romance"},
                    {name: "The Phantom's Curse", description: "A horror novel unveiling the terrifying curse of a vengeful phantom haunting a small town.", author: "Paul Fright", genre: "Horror"},
                    {name: "The Quest for Truth", description: "An enlightening philosophical tale delving into life's deepest questions and the pursuit of truth.", author: "Quinn Quest", genre: "Philosophy"},
                    {name: "The Riddle of Fate", description: "A thrilling mystery novel filled with mind-bending riddles, unexpected twists, and a fight against time.", author: "Rachel Riddle", genre: "Mystery"},
                    {name: "The Stars Above", description: "A poetic narrative exploring the beauty and mysteries of the cosmos through the eyes of a dreamer.", author: "Stella Cosmos", genre: "Poetry"},
                    {name: "The Tides of Change", description: "A compelling drama depicting the lives of a family adapting to societal changes during a turbulent era.", author: "Tina Tide", genre: "Drama"},
                    {name: "The Unknown Beyond", description: "A captivating science fiction novel exploring the limitless possibilities of the unknown beyond human comprehension.", author: "Ulysses Universe", genre: "Science Fiction"},
                    {name: "The Voice of Silence", description: "An evocative novel portraying the profound impact of silence in conveying unspoken emotions and truths.", author: "Vera Voice", genre: "Literary Fiction"},
                    {name: "The Whispers of War", description: "A war novel illustrating the harsh realities, unbreakable bonds, and the indomitable spirit of soldiers.", author: "Warren Warrior", genre: "War"},
                    {name: "The Xanadu Adventure", description: "An adventurous tale of a group of explorers discovering the mythical city of Xanadu and its hidden secrets.", author: "Xander Explorer", genre: "Adventure"},
                    {name: "The Yesteryear Chronicle", description: "A nostalgic narrative reminiscing the simple yet profound moments of yesteryears and the lessons they impart.", author: "Yara Yesterday", genre: "Literary Fiction"},
                    {name: "The Zenith of Love", description: "A romance novel exploring the pinnacle of love, the trials and tribulations, and the power of unwavering affection.", author: "Zara Zenith", genre: "Romance"},
                    {name: "The Alpha Quest", description: "An epic quest of heroes rising against the odds to restore peace in a land overrun by evil.", author: "Aaron Alpha", genre: "Fantasy"},
                    {name: "The Bravo Brigade", description: "A military thriller following an elite group of soldiers on a high-stakes mission in enemy territory.", author: "Barbara Bravo", genre: "Thriller"},
                    {name: "The Charmed Circle", description: "A magical tale of a group of enchanted beings battling dark forces to save their enchanted realm.", author: "Charlie Charm", genre: "Fantasy"},
                    {name: "The Delta Dilemma", description: "A riveting political thriller unveiling a conspiracy that could change the course of history.", author: "Diana Delta", genre: "Political Thriller"},
                    {name: "The Echo of Eternity", description: "A philosophical exploration of existence, the cosmos, and the search for eternal truths.", author: "Eddie Echo", genre: "Philosophy"},
                    {name: "The Foxtrot Fantasy", description: "A whimsical tale of a magical dance competition where the stakes are higher than ever before.", author: "Fiona Foxtrot", genre: "Fantasy"},
                    {name: "The Golf Galaxy", description: "An amusing narrative of a golfer finding himself in a galaxy where golf is the key to saving civilizations.", author: "Gary Golf", genre: "Science Fiction"},
                    {name: "The Hotel of Horrors", description: "A bone-chilling horror story set in an old, haunted hotel with a dark and sinister history.", author: "Helen Horror", genre: "Horror"},
                    {name: "The India Illusion", description: "A mesmerizing tale of a man's journey through the mystical and diverse landscapes of India, discovering ancient secrets.", author: "Indira Imagery", genre: "Adventure"},
                    {name: "The Juliet Journal", description: "A contemporary romance novel told through the heartfelt journal entries of a young woman navigating love and life.", author: "Julia Juliet", genre: "Romance"},
                    {name: "The Kilo Kingdom", description: "An intriguing tale of power struggles, betrayal, and the quest for justice in a medieval kingdom.", author: "Kingston Knight", genre: "Historical Fiction"},
                    {name: "The Lima Legacy", description: "A gripping family drama uncovering long-buried secrets, rivalries, and the enduring legacy of a powerful dynasty.", author: "Linda Legacy", genre: "Drama"},
                    {name: "The Mike Mystery", description: "A detective novel following the enigmatic Detective Mike solving a series of complex and high-profile cases.", author: "Mike Mystery", genre: "Mystery"},
                    {name: "The November Nocturne", description: "A poetic anthology capturing the melancholy and beauty of November nights.", author: "Nina Nocturne", genre: "Poetry"},
                    {name: "The Oscar Odyssey", description: "An epic odyssey of a young warrior's quest to reclaim his homeland and honor.", author: "Oscar Odyssey", genre: "Adventure"},
                    {name: "The Papa Paradox", description: "A thought-provoking science fiction exploring paradoxes, alternate realities, and the complex nature of the universe.", author: "Peter Paradox", genre: "Science Fiction"},
                    {name: "The Quill Quest", description: "A fantastical adventure of a young writer with a magical quill, embarking on a quest to save her kingdom.", author: "Quincy Quill", genre: "Fantasy"},
                    {name: "The Romeo Revolution", description: "A historical romance set against the backdrop of a revolution, portraying love, loss, and the fight for freedom.", author: "Romeo Revolution", genre: "Historical Romance"},
                    {name: "The Sierra Secret", description: "A mystery novel uncovering the deep-seated secrets of a small town nestled in the picturesque Sierra Mountains.", author: "Sierra Secret", genre: "Mystery"},
                    {name: "The Tango Tragedy", description: "A compelling drama of a famed dance duo facing love, rivalry, and the haunting shadows of the past.", author: "Tina Tango", genre: "Drama"},
                    {name: "The Umbra Universe", description: "A cosmic adventure through the dark and unknown realms of the universe, unveiling awe-inspiring phenomena.", author: "Ulysses Universe", genre: "Science Fiction"},
                    {name: "The Victor Victory", description: "An inspiring sports drama of an underdog athlete's journey to victory against all odds.", author: "Victor Victory", genre: "Sports Drama"},
                    {name: "The Whiskey Whisper", description: "A thrilling crime novel set in the underground world of illicit whiskey trade and the chase to bring justice.", author: "William Whiskey", genre: "Crime"}
                ]) {
                    affected_rows
                }
                }
                """)
client.execute(gql_query)
